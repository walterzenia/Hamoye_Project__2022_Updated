# %%
#Importing necessary libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
crime_data = pd.read_csv(r"C:\Users\gbeme\Desktop\crimes_against_women_2001-2014.csv")
crime_data.head()
# Out:
#    Unnamed: 0        STATE/UT       DISTRICT  Year  Rape  \
# 0           0  ANDHRA PRADESH       ADILABAD  2001    50
# 1           1  ANDHRA PRADESH      ANANTAPUR  2001    23
# 2           2  ANDHRA PRADESH       CHITTOOR  2001    27
# 3           3  ANDHRA PRADESH       CUDDAPAH  2001    20
# 4           4  ANDHRA PRADESH  EAST GODAVARI  2001    23
#
#    Kidnapping and Abduction  Dowry Deaths  \
# 0                        30            16
# 1                        30             7
# 2                        34            14
# 3                        20            17
# 4                        26            12
#
#    Assault on women with intent to outrage her modesty  \
# 0                                                149
# 1                                                118
# 2                                                112
# 3                                                126
# 4                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
# 2                          83                                  186
# 3                          38                                   57
# 4                          58                                  247
#
#    Importation of Girls
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
crime_data.isnull().sum()
# Out:
# Unnamed: 0                                             0
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
#Check for duplicated entries
crime_data.duplicated().sum()
# Out:
# 0

# %%
#Display the list of all states in alphabetical order
list_of_states= crime_data['STATE/UT'].unique()
list_of_states.sort()
print(list_of_states)
# Out:
# ['A & N ISLANDS' 'A & N Islands' 'A&N Islands' 'ANDHRA PRADESH'
#  'ARUNACHAL PRADESH' 'ASSAM' 'Andhra Pradesh' 'Arunachal Pradesh' 'Assam'
#  'BIHAR' 'Bihar' 'CHANDIGARH' 'CHHATTISGARH' 'Chandigarh' 'Chhattisgarh'
#  'D & N HAVELI' 'D&N Haveli' 'DAMAN & DIU' 'DELHI' 'Daman & Diu'
#  'Delhi UT' 'GOA' 'GUJARAT' 'Goa' 'Gujarat' 'HARYANA' 'HIMACHAL PRADESH'
#  'Haryana' 'Himachal Pradesh' 'JAMMU & KASHMIR' 'JHARKHAND'
#  'Jammu & Kashmir' 'Jharkhand' 'KARNATAKA' 'KERALA' 'Karnataka' 'Kerala'
#  'LAKSHADWEEP' 'Lakshadweep' 'MADHYA PRADESH' 'MAHARASHTRA' 'MANIPUR'
#  'MEGHALAYA' 'MIZORAM' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'NAGALAND' 'Nagaland' 'ODISHA' 'Odisha'
#  'PUDUCHERRY' 'PUNJAB' 'Puducherry' 'Punjab' 'RAJASTHAN' 'Rajasthan'
#  'SIKKIM' 'Sikkim' 'TAMIL NADU' 'TRIPURA' 'Tamil Nadu' 'Telangana'
#  'Tripura' 'UTTAR PRADESH' 'UTTARAKHAND' 'Uttar Pradesh' 'Uttarakhand'
#  'WEST BENGAL' 'West Bengal']

# %%
#statistical description of the numerical data in the dataset
crime_data.describe()
# Out:
#          Unnamed: 0          Year          Rape  Kidnapping and Abduction  \
# count  10677.000000  10677.000000  10677.000000              10677.000000
# mean    3871.570198   2007.697949     57.989885                 69.888358
# std     2816.369918      4.046874    214.230398                311.623450
# min        0.000000   2001.000000      0.000000                  0.000000
# 25%     1009.000000   2004.000000      8.000000                  6.000000
# 50%     3678.000000   2008.000000     22.000000                 20.000000
# 75%     6347.000000   2011.000000     44.000000                 49.000000
# max     9016.000000   2014.000000   5076.000000              10626.000000
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# count  10677.000000                                       10677.000000
# mean      20.181699                                         113.539196
# std       98.276531                                         458.903951
# min        0.000000                                           0.000000
# 25%        1.000000                                          10.000000
# 50%        5.000000                                          34.000000
# 75%       16.000000                                          85.000000
# max     2469.000000                                       10001.000000
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# count                10677.000000                         10677.000000
# mean                    27.419313                           209.224314
# std                    167.806797                           905.664362
# min                      0.000000                             0.000000
# 25%                      0.000000                            11.000000
# 50%                      2.000000                            50.000000
# 75%                     12.000000                           144.000000
# max                   4970.000000                         23278.000000
#
#        Importation of Girls
# count          10677.000000
# mean               0.175330
# std                2.228637
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max               83.000000

# %%
crime_data.dtypes
# Out:
# Unnamed: 0                                              int64
# STATE/UT                                               object
# DISTRICT                                               object
# Year                                                    int64
# Rape                                                    int64
# Kidnapping and Abduction                                int64
# Dowry Deaths                                            int64
# Assault on women with intent to outrage her modesty     int64
# Insult to modesty of Women                              int64
# Cruelty by Husband or his Relatives                     int64
# Importation of Girls                                    int64
# dtype: object

# %%
#Dropping 'Unnamed: 0 '  name
crime_data.drop('Unnamed: 0', axis = 1, inplace = True)

# %% [markdown]
# **Data Cleaning on STATE/UT Column**
#
# In India we have only 36 States/UT but there is a total of 72 unique States/UT present in the dataset, so we take a deep dive into finding the errors and fixing it. It was noticed that some of the States/UT were repeated in another case (i.e we had pairs of the same state in both upper and lower cases) and this was fixed.

# %%
#Checking for the number of States/UT present in the dataset
len(list_of_states)
# Out:
# 72

# %%
def convert_to_lowercase(row):
    '''This function takes in a row argument and converts that row into a lowercase'''
    row = row['STATE/UT'].strip()
    row = row.lower()
    return row

crime_data['STATE/UT'] = crime_data.apply(convert_to_lowercase, axis=1)

# %%
#Replacing column names with the appropriate name
crime_data['STATE/UT'].replace("a&n islands", "a & n islands", inplace = True)
crime_data['STATE/UT'].replace("d&n haveli", "d & n haveli", inplace = True)
crime_data['STATE/UT'].replace("delhi ut", "delhi", inplace = True)

# %%
#Checking for the number of States/UT now present in the dataset after cleaning
len(list(crime_data["STATE/UT"].unique()))
# Out:
# 36

# %%
#Create a new column named Total which represents the total number of crimes
crime_data["Total"]=crime_data["Rape"]+crime_data["Kidnapping and Abduction"]+crime_data["Dowry Deaths"]+crime_data["Assault on women with intent to outrage her modesty"]+crime_data["Insult to modesty of Women"]+crime_data["Cruelty by Husband or his Relatives"]+crime_data["Importation of Girls"]

# %%
#nameing variables
columns=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls','Total']
crimes=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls']

# %% [markdown]
# **YEAR BY YEAR ANALYSIS**

# %%
annual_crimes = crime_data.groupby('Year').sum()
print('Total number of crimes from 2001 to 2014 ')

annual_crimes
# Out:
# Total number of crimes from 2001 to 2014
#        Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2001  32150                     29290         13702
# 2002  32746                     29012         13644
# 2003  31694                     26592         12416
# 2004  36466                     31156         14052
# 2005  36718                     31500         13574
# 2006  38696                     34828         15236
# 2007  41474                     40832         16186
# 2008  42934                     45878         16344
# 2009  42794                     51482         16766
# 2010  44344                     59590         16782
# 2011  48412                     71130         17236
# 2012  49846                     76524         16466
# 2013  67414                    103762         16166
# 2014  73470                    114622         16910
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2001                                              68248
# 2002                                              67886
# 2003                                              65878
# 2004                                              69134
# 2005                                              68350
# 2006                                              73234
# 2007                                              77468
# 2008                                              80826
# 2009                                              77422
# 2010                                              81226
# 2011                                              85936
# 2012                                              90702
# 2013                                             141478
# 2014                                             164470
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2001                       19492                                98340
# 2002                       20310                                98474
# 2003                       24650                               101406
# 2004                       20002                               116242
# 2005                       19968                               116638
# 2006                       19932                               126256
# 2007                       21900                               151860
# 2008                       24428                               162688
# 2009                       22018                               179092
# 2010                       19922                               188082
# 2011                       17140                               198270
# 2012                       18346                               213054
# 2013                       25178                               237732
# 2014                       19470                               245754
#
#       Importation of Girls   Total
# Year
# 2001                   228  261450
# 2002                   152  262224
# 2003                    92  262728
# 2004                   178  287230
# 2005                   298  287046
# 2006                   134  308316
# 2007                   122  349842
# 2008                   134  373232
# 2009                    96  389670
# 2010                    72  410018
# 2011                   160  438284
# 2012                   118  465056
# 2013                    62  591792
# 2014                    26  634722

# %%
yearly_crimes= annual_crimes.drop(columns='Total')
crime_data.groupby('STATE/UT').sum().sort_values(by='Total', ascending=False)
# Out:
#                       Year   Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# uttar pradesh      2071847  51150                    135906         57256
# andhra pradesh      853205  32150                     34504         13844
# west bengal         742858  47876                     61158         12308
# rajasthan          1086259  45684                     66278         11854
# madhya pradesh     1483646  90996                     35608         21090
# maharashtra        1294844  48974                     30368          9696
# assam               851246  40190                     62074          3268
# kerala              554128  20030                      4452           700
# gujarat             925590  11644                     34670          1108
# bihar              1268753  30758                     57086         32206
# odisha             1011829  30480                     25588         10782
# karnataka           947638  15056                     16262          7016
# tamil nadu         1108202  16660                     30908          5060
# delhi               445800  20312                     46586          3758
# haryana             638456  17110                     20016          7372
# chhattisgarh        650581  29308                     11808          2758
# jharkhand           734793  22826                     14186          7896
# punjab              746875  14656                     15096          3524
# jammu & kashmir     771023   7038                     21164           294
# tripura             174741   5060                      2202           752
# uttarakhand         393470   3752                      6484          1974
# himachal pradesh    417608   4674                      4116           112
# telangana            28196   1958                      1422           578
# chandigarh           56210    770                      1682            90
# manipur             295127   1068                      2606             6
# meghalaya           240948   2642                       670            36
# arunachal pradesh   469844   1316                      1470             6
# mizoram             258985   2070                        30             8
# goa                  86329   1062                       640            38
# puducherry           74300    208                       306            56
# a & n islands        88347    336                       212            20
# sikkim              142539    570                       180             4
# nagaland            325239    562                       190             2
# d & n haveli         56210    132                       224             2
# daman & diu          84315     60                        44             6
# lakshadweep          56210     20                         2             0
#
#                    Assault on women with intent to outrage her modesty  \
# STATE/UT
# uttar pradesh                                                  91212
# andhra pradesh                                                126952
# west bengal                                                    66908
# rajasthan                                                      83362
# madhya pradesh                                                195478
# maharashtra                                                   114704
# assam                                                          38256
# kerala                                                         80438
# gujarat                                                        23186
# bihar                                                          16958
# odisha                                                         80214
# karnataka                                                      65750
# tamil nadu                                                     43404
# delhi                                                          30742
# haryana                                                        17142
# chhattisgarh                                                   47096
# jharkhand                                                       9898
# punjab                                                         12410
# jammu & kashmir                                                28638
# tripura                                                         7344
# uttarakhand                                                     4366
# himachal pradesh                                                9256
# telangana                                                       6376
# chandigarh                                                      1088
# manipur                                                         1322
# meghalaya                                                       1470
# arunachal pradesh                                               1996
# mizoram                                                         1988
# goa                                                             1384
# puducherry                                                      1314
# a & n islands                                                    600
# sikkim                                                           586
# nagaland                                                         260
# d & n haveli                                                     106
# daman & diu                                                       40
# lakshadweep                                                       14
#
#                    Insult to modesty of Women  \
# STATE/UT
# uttar pradesh                           53130
# andhra pradesh                          86964
# west bengal                              5348
# rajasthan                                 794
# madhya pradesh                          20964
# maharashtra                             32634
# assam                                     254
# kerala                                   7930
# gujarat                                  3230
# bihar                                     694
# odisha                                   7488
# karnataka                                2276
# tamil nadu                              21170
# delhi                                    7928
# haryana                                 17866
# chhattisgarh                             3968
# jharkhand                                 566
# punjab                                   1728
# jammu & kashmir                          9168
# tripura                                   114
# uttarakhand                              3190
# himachal pradesh                         1220
# telangana                                2284
# chandigarh                                342
# manipur                                     6
# meghalaya                                 124
# arunachal pradesh                          48
# mizoram                                    70
# goa                                       468
# puducherry                                600
# a & n islands                             112
# sikkim                                     34
# nagaland                                   24
# d & n haveli                               12
# daman & diu                                 4
# lakshadweep                                 4
#
#                    Cruelty by Husband or his Relatives  Importation of Girls  \
# STATE/UT
# uttar pradesh                                   193738                     6
# andhra pradesh                                  280906                    34
# west bengal                                     344124                   254
# rajasthan                                       262200                    14
# madhya pradesh                                  102816                   134
# maharashtra                                     193202                     6
# assam                                           115300                    22
# kerala                                          111626                     0
# gujarat                                         146468                     0
# bihar                                            69770                   904
# odisha                                           49206                    36
# karnataka                                        72706                    94
# tamil nadu                                       45524                    30
# delhi                                            42834                     2
# haryana                                          68414                     4
# chhattisgarh                                     23436                    12
# jharkhand                                        23910                   298
# punjab                                           30840                     4
# jammu & kashmir                                   5390                     0
# tripura                                          16086                     0
# uttarakhand                                       9756                     2
# himachal pradesh                                  7796                     0
# telangana                                        12738                     0
# chandigarh                                        2080                     0
# manipur                                            578                     0
# meghalaya                                          460                     8
# arunachal pradesh                                  476                     0
# mizoram                                            134                     6
# goa                                                532                     0
# puducherry                                         234                     0
# a & n islands                                      288                     0
# sikkim                                             108                     0
# nagaland                                            32                     2
# d & n haveli                                        90                     0
# daman & diu                                         76                     0
# lakshadweep                                         14                     0
#
#                     Total
# STATE/UT
# uttar pradesh      582398
# andhra pradesh     575354
# west bengal        537976
# rajasthan          470186
# madhya pradesh     467086
# maharashtra        429584
# assam              259364
# kerala             225176
# gujarat            220306
# bihar              208376
# odisha             203794
# karnataka          179160
# tamil nadu         162756
# delhi              152162
# haryana            147924
# chhattisgarh       118386
# jharkhand           79580
# punjab              78258
# jammu & kashmir     71692
# tripura             31558
# uttarakhand         29524
# himachal pradesh    27174
# telangana           25356
# chandigarh           6052
# manipur              5586
# meghalaya            5410
# arunachal pradesh    5312
# mizoram              4306
# goa                  4124
# puducherry           2718
# a & n islands        1568
# sikkim               1482
# nagaland             1072
# d & n haveli          566
# daman & diu           230
# lakshadweep            54

# %% [markdown]
# # VISUALIZATIONS

# %%
#Bar plot of total crimes commited yearly
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


ax.grid(linestyle="--",axis="y",color='gray')

lower_year=2001
upper_year=2014
arr=np.array([i for i in range(lower_year, upper_year+1)])

a=sns.barplot(data=annual_crimes,x=arr,y='Total',palette='rocket_r')
ax.set_xticklabels(ax.get_xticklabels(),rotation =30)
plt.text(0.5,540000,"Crime rate against women increases year by year",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total",fontweight='bold')
plt.title("Total Number Of Crimes In Each Year",fontweight='bold',fontsize=20)

plt.show()

# %% [markdown]
# **Annual crime variation**

# %%
def plotting_cat_features(nrows,ncols,cat_columns):
    
    f,ax=plt.subplots(nrows=nrows,ncols=ncols,figsize=(16,25))
    f.patch.set_facecolor('#F2EDD7FF')
    
    #Setting background and foreground color
    for i in range(0,nrows):
        for j in range(0,ncols):
            ax[i][j].set_facecolor('#F2EDD7FF')

    #Plotting count plot 
    for i in range(0,nrows):
        for j in range(0,ncols):
            a1=sns.barplot(data=annual_crimes,x=annual_crimes.index,y=cat_columns[i*(nrows-2)+j],palette='rocket_r',ax=ax[i][j])

        
            #Dealing with spines
            ax[i][j].grid(linestyle="--",axis='y',color='gray')
    plt.show()

# %%
print("How was each crime varying year by year?")
print()
plotting_cat_features(4,2,columns)
# Out:
# How was each crime varying year by year?

# %% [markdown]
# **CRIME RATE INCREMENT YEAR BY YEAR**

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

ax.grid(linestyle="--",axis="y",color='gray')

lower_year=2001
upper_year=2014

arr=np.array([i for i in range(lower_year,upper_year+1)])

a=sns.lineplot(data=annual_crimes,palette='rocket_r',linestyle="dashed")#,x=arr,y='Rape',hue_order=crimes,palette='rocket_r')

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
#plt.text(0.5,540000,"Crime rate against women increases year by year",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("crime rate",fontweight='bold')
plt.title("Crime Rate against Women in India",fontweight='bold',fontsize=20)
plt.show()
# Out:
# C:\Users\gbeme\AppData\Local\Temp/ipykernel_16964/3476018771.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# **DISTRIBUTION OF EACH CRIME CATEGORY FROM 2001 TO 2014 REPRESENTED IN A PIE CHART**

# %%
top_crimes=pd.DataFrame(columns=['crimes',"total"])
for crime in crimes:
    top_crimes=top_crimes.append({'crimes':crime ,'total':crime_data[crime].sum(axis=0)},ignore_index=True)
    
top_crimes=top_crimes.sort_values(by='total',ascending=False)

top_crimes

list_crimes_number=list(top_crimes['total'])
list_crimes=list(top_crimes['crimes'])
fig=plt.figure(figsize=(12,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

colors=['green', 'gold', 'lightskyblue', 'lightcoral','lightpink','red','teal']
#patches,text=plt.pie(list_crimes_number,colors=colors,labels=list_crimes_number,autopct='%1.1f%%')
plt.pie(list_crimes_number,colors=colors,labels=list_crimes,autopct='%1.2f%%', explode=[0.03,0.0,0.0,0.0,0.0,0.07,0.1], shadow=True)
#plt.legend()
plt.title("Distribution of Crimes from 2001 to 2014",fontweight='bold',fontsize=16)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# **TOTAL NUMBER OF EACH CRIME CATEGORY FROM 2001 TO 2014 REPRESENTED WITH A BAR CHART**

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=top_crimes,y='total',x='crimes', color='brown')
ax.set_xticklabels(ax.get_xticklabels(),rotation =40)
#plt.text(0.5,540000,"Crime rate against women increases year by year",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("total_crimes",fontweight='bold')
plt.text(2,1700000, "Highest No. of crime: Cruelty by Husband\n\nLowest No. of Crime: Importation of Girls",fontweight='bold',fontsize=15)

plt.show()

# %% [markdown]
# **COMPARISON BETWEEN CRIME CATEGORIES IN 2001 AND 2014**

# %%
crimedata_2001=annual_crimes.loc[annual_crimes.index==2001]
crimedata_2014=annual_crimes.loc[annual_crimes.index==2014]

crimedata_2001=crimedata_2001.drop(["Total"],axis=1)
crimedata_2014=crimedata_2014.drop(["Total"],axis=1)
crimes_in_2001=list(crimedata_2001.iloc[0])
crimes_in_2014=list(crimedata_2014.iloc[0])

f,ax=plt.subplots(1,2,figsize=(20,8))
f.patch.set_facecolor('#F2EDD7FF')
#Setting background and foreground color
for j in range(0,2):
    ax[j].set_facecolor('#F2EDD7FF')
    
ax[0].pie(crimes_in_2001,autopct='%1.2f%%')
ax[0].text(0,1.4,"2001",fontweight='bold',fontsize=20)
ax[1].pie(crimes_in_2014,autopct='%1.2f%%')
ax[0].text(3.4,1.4,"2014",fontweight='bold',fontsize=20)
ax[0].legend(labels=crimedata_2001.columns,loc='lower right')

plt.show()

# %% [markdown]
# **STATE BY STATE ANALYSIS**

# %%
print("*** Total number of Unique States/Union Territories we have in Data ***")
print()
states=crime_data['STATE/UT'].unique()
print("Number of states/territories without duplicates: ", len(states))
print()
print(states)
# Out:
# *** Total number of Unique States/Union Territories we have in Data ***
#
# Number of states/territories without duplicates:  36
#
# ['andhra pradesh' 'arunachal pradesh' 'assam' 'bihar' 'chhattisgarh' 'goa'
#  'gujarat' 'haryana' 'himachal pradesh' 'jammu & kashmir' 'jharkhand'
#  'karnataka' 'kerala' 'madhya pradesh' 'maharashtra' 'manipur' 'meghalaya'
#  'mizoram' 'nagaland' 'odisha' 'punjab' 'rajasthan' 'sikkim' 'tamil nadu'
#  'tripura' 'uttar pradesh' 'uttarakhand' 'west bengal' 'a & n islands'
#  'chandigarh' 'd & n haveli' 'daman & diu' 'delhi' 'lakshadweep'
#  'puducherry' 'telangana']

# %%
state_crimedata=pd.DataFrame()
for crime in columns:
    state_crimes=crime_data.groupby(['STATE/UT'])[crime].sum()
    state_crimedata[crime]=state_crimes

print("***** Each cateogry of crimes in each state from 2001 to 2014 *****")
print()
state_crimedata=state_crimedata.sort_values(by='Total',ascending=False)
state_crimedata.reset_index()
# Out:
# ***** Each cateogry of crimes in each state from 2001 to 2014 *****
#              STATE/UT   Rape  Kidnapping and Abduction  Dowry Deaths  \
# 0       uttar pradesh  51150                    135906         57256
# 1      andhra pradesh  32150                     34504         13844
# 2         west bengal  47876                     61158         12308
# 3           rajasthan  45684                     66278         11854
# 4      madhya pradesh  90996                     35608         21090
# 5         maharashtra  48974                     30368          9696
# 6               assam  40190                     62074          3268
# 7              kerala  20030                      4452           700
# 8             gujarat  11644                     34670          1108
# 9               bihar  30758                     57086         32206
# 10             odisha  30480                     25588         10782
# 11          karnataka  15056                     16262          7016
# 12         tamil nadu  16660                     30908          5060
# 13              delhi  20312                     46586          3758
# 14            haryana  17110                     20016          7372
# 15       chhattisgarh  29308                     11808          2758
# 16          jharkhand  22826                     14186          7896
# 17             punjab  14656                     15096          3524
# 18    jammu & kashmir   7038                     21164           294
# 19            tripura   5060                      2202           752
# 20        uttarakhand   3752                      6484          1974
# 21   himachal pradesh   4674                      4116           112
# 22          telangana   1958                      1422           578
# 23         chandigarh    770                      1682            90
# 24            manipur   1068                      2606             6
# 25          meghalaya   2642                       670            36
# 26  arunachal pradesh   1316                      1470             6
# 27            mizoram   2070                        30             8
# 28                goa   1062                       640            38
# 29         puducherry    208                       306            56
# 30      a & n islands    336                       212            20
# 31             sikkim    570                       180             4
# 32           nagaland    562                       190             2
# 33       d & n haveli    132                       224             2
# 34        daman & diu     60                        44             6
# 35        lakshadweep     20                         2             0
#
#     Assault on women with intent to outrage her modesty  \
# 0                                               91212
# 1                                              126952
# 2                                               66908
# 3                                               83362
# 4                                              195478
# 5                                              114704
# 6                                               38256
# 7                                               80438
# 8                                               23186
# 9                                               16958
# 10                                              80214
# 11                                              65750
# 12                                              43404
# 13                                              30742
# 14                                              17142
# 15                                              47096
# 16                                               9898
# 17                                              12410
# 18                                              28638
# 19                                               7344
# 20                                               4366
# 21                                               9256
# 22                                               6376
# 23                                               1088
# 24                                               1322
# 25                                               1470
# 26                                               1996
# 27                                               1988
# 28                                               1384
# 29                                               1314
# 30                                                600
# 31                                                586
# 32                                                260
# 33                                                106
# 34                                                 40
# 35                                                 14
#
#     Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                        53130                               193738
# 1                        86964                               280906
# 2                         5348                               344124
# 3                          794                               262200
# 4                        20964                               102816
# 5                        32634                               193202
# 6                          254                               115300
# 7                         7930                               111626
# 8                         3230                               146468
# 9                          694                                69770
# 10                        7488                                49206
# 11                        2276                                72706
# 12                       21170                                45524
# 13                        7928                                42834
# 14                       17866                                68414
# 15                        3968                                23436
# 16                         566                                23910
# 17                        1728                                30840
# 18                        9168                                 5390
# 19                         114                                16086
# 20                        3190                                 9756
# 21                        1220                                 7796
# 22                        2284                                12738
# 23                         342                                 2080
# 24                           6                                  578
# 25                         124                                  460
# 26                          48                                  476
# 27                          70                                  134
# 28                         468                                  532
# 29                         600                                  234
# 30                         112                                  288
# 31                          34                                  108
# 32                          24                                   32
# 33                          12                                   90
# 34                           4                                   76
# 35                           4                                   14
#
#     Importation of Girls   Total
# 0                      6  582398
# 1                     34  575354
# 2                    254  537976
# 3                     14  470186
# 4                    134  467086
# 5                      6  429584
# 6                     22  259364
# 7                      0  225176
# 8                      0  220306
# 9                    904  208376
# 10                    36  203794
# 11                    94  179160
# 12                    30  162756
# 13                     2  152162
# 14                     4  147924
# 15                    12  118386
# 16                   298   79580
# 17                     4   78258
# 18                     0   71692
# 19                     0   31558
# 20                     2   29524
# 21                     0   27174
# 22                     0   25356
# 23                     0    6052
# 24                     0    5586
# 25                     8    5410
# 26                     0    5312
# 27                     6    4306
# 28                     0    4124
# 29                     0    2718
# 30                     0    1568
# 31                     0    1482
# 32                     2    1072
# 33                     0     566
# 34                     0     230
# 35                     0      54

# %% [markdown]
# BAR CHART REPRESENTATION OF TOTAL NUMBER OF CRIMES IN EACH STATE

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(20,10))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=state_crimedata,x=state_crimedata.index,y='Total',color='brown')

ax.set_xticklabels(ax.get_xticklabels(),rotation = 70)
plt.text(16,520000,"Crime Rte Against State Wise\nState with highest crimes: UttarPradesh 10.9%\nState with lowest crimes: Lashadweep 0.01%",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total",fontweight='bold')
plt.title("Total Number Of Crimes In Each State/UT",fontweight='bold',fontsize=20)

plt.show()

# %% [markdown]
# **TOP 5 STATES/UT WITH HIGHEST CRIME RATES 2001 to 2014**
# 1. Uttar Pradesh
# 2. Andhra Pradesh
# 3. West Bengal
# 4. Rajasthan
# 5. Madhya Pradesh

# %%
state_crimedata.head()
# Out:
#                  Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# uttar pradesh   51150                    135906         57256
# andhra pradesh  32150                     34504         13844
# west bengal     47876                     61158         12308
# rajasthan       45684                     66278         11854
# madhya pradesh  90996                     35608         21090
#
#                 Assault on women with intent to outrage her modesty  \
# STATE/UT
# uttar pradesh                                               91212
# andhra pradesh                                             126952
# west bengal                                                 66908
# rajasthan                                                   83362
# madhya pradesh                                             195478
#
#                 Insult to modesty of Women  \
# STATE/UT
# uttar pradesh                        53130
# andhra pradesh                       86964
# west bengal                           5348
# rajasthan                              794
# madhya pradesh                       20964
#
#                 Cruelty by Husband or his Relatives  Importation of Girls  \
# STATE/UT
# uttar pradesh                                193738                     6
# andhra pradesh                               280906                    34
# west bengal                                  344124                   254
# rajasthan                                    262200                    14
# madhya pradesh                               102816                   134
#
#                  Total
# STATE/UT
# uttar pradesh   582398
# andhra pradesh  575354
# west bengal     537976
# rajasthan       470186
# madhya pradesh  467086

# %% [markdown]
# **FIVE STATES/UT WITH LEAST CRIME RATES 2001 to 2014**
# 1. Sikkim
# 2. Nagaland
# 3. d&nhaveli
# 4. daman&diu
# 5. lakshadweep

# %%
state_crimedata.tail()
# Out:
#               Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# sikkim         570                       180             4
# nagaland       562                       190             2
# d & n haveli   132                       224             2
# daman & diu     60                        44             6
# lakshadweep     20                         2             0
#
#               Assault on women with intent to outrage her modesty  \
# STATE/UT
# sikkim                                                      586
# nagaland                                                    260
# d & n haveli                                                106
# daman & diu                                                  40
# lakshadweep                                                  14
#
#               Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# STATE/UT
# sikkim                                34                                  108
# nagaland                              24                                   32
# d & n haveli                          12                                   90
# daman & diu                            4                                   76
# lakshadweep                            4                                   14
#
#               Importation of Girls  Total
# STATE/UT
# sikkim                           0   1482
# nagaland                         2   1072
# d & n haveli                     0    566
# daman & diu                      0    230
# lakshadweep                      0     54

# %% [markdown]
# **TOP FIVE STATES WITH HIGHEST NUMBER OF RAPE CRIME**

# %%
state_rape=state_crimedata.sort_values(by="Rape",ascending=False)
high_rape=state_rape.iloc[:,:1].head()
high_rape.reset_index(inplace=True)
high_rape
# Out:
#          STATE/UT   Rape
# 0  madhya pradesh  90996
# 1   uttar pradesh  51150
# 2     maharashtra  48974
# 3     west bengal  47876
# 4       rajasthan  45684

# %% [markdown]
# **TOP FIVE STATES WITH HIGHEST NUMBER OF ASSAULT ON WOMEN CRIME**

# %%
crime_state_assault=state_crimedata.sort_values(by='Assault on women with intent to outrage her modesty',ascending=False)
high_assault=crime_state_assault.iloc[:,[3]].head()
high_assault
# Out:
#                 Assault on women with intent to outrage her modesty
# STATE/UT
# madhya pradesh                                             195478
# andhra pradesh                                             126952
# maharashtra                                                114704
# uttar pradesh                                               91212
# rajasthan                                                   83362

# %% [markdown]
# **TOP FIVE STATES WITH HIGHEST NUMBER OF KIDNAPPING AND ABDUCTION CRIME**

# %%
state_kidnapping=state_crimedata.sort_values(by='Kidnapping and Abduction',ascending=False)
high_kidnapping=state_kidnapping.iloc[:,[1]].head()
high_kidnapping
# Out:
#                Kidnapping and Abduction
# STATE/UT
# uttar pradesh                    135906
# rajasthan                         66278
# assam                             62074
# west bengal                       61158
# bihar                             57086

# %% [markdown]
# **TOP FIVE STATES WITH HIGHEST NUMBER OF DOWRY DEATHS**

# %%
state_dowry=state_crimedata.sort_values(by='Dowry Deaths',ascending=False)
high_dowry=state_dowry.iloc[:,[2]].head()
high_dowry
# Out:
#                 Dowry Deaths
# STATE/UT
# uttar pradesh          57256
# bihar                  32206
# madhya pradesh         21090
# andhra pradesh         13844
# west bengal            12308

# %% [markdown]
# **TOP FIVE STATES WITH HIGHEST NUMBER OF INSULT TO MODESTY OF WOMEN**

# %%
state_modesty=state_crimedata.sort_values(by='Insult to modesty of Women',ascending=False)
high_modesty=state_modesty.iloc[:,[4]].head()
high_modesty
# Out:
#                 Insult to modesty of Women
# STATE/UT
# andhra pradesh                       86964
# uttar pradesh                        53130
# maharashtra                          32634
# tamil nadu                           21170
# madhya pradesh                       20964

# %% [markdown]
# **TOP FIVE STATES WITH HIGHEST NUMBER OF CRUELTY BY HUSBAND CRIME**

# %%
state_cruelty =state_crimedata.sort_values(by='Cruelty by Husband or his Relatives',ascending=False)
high_cruelty=state_cruelty.iloc[:,[5]].head()
high_cruelty
# Out:
#                 Cruelty by Husband or his Relatives
# STATE/UT
# west bengal                                  344124
# andhra pradesh                               280906
# rajasthan                                    262200
# uttar pradesh                                193738
# maharashtra                                  193202

# %% [markdown]
# **TOP FIVE STATES WITH HIGHEST NUMBER OF IMPORTATION OF GIRLS CRIME**

# %%
state_importation=state_crimedata.sort_values(by='Importation of Girls',ascending=False)
high_importation=state_importation.iloc[:,[6]].head()
high_importation
# Out:
#                 Importation of Girls
# STATE/UT
# bihar                            904
# jharkhand                        298
# west bengal                      254
# madhya pradesh                   134
# karnataka                         94

# %% [markdown]
# ### **We will examine top three states with highest crime rates**

# %% [markdown]
# #### Crime rate in **Uttar Pradesh (UP)**

# %%
crimedata_up=state_crimedata.loc[state_crimedata.index=='uttar pradesh']
crimedata_up
# Out:
#                 Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# uttar pradesh  51150                    135906         57256
#
#                Assault on women with intent to outrage her modesty  \
# STATE/UT
# uttar pradesh                                              91212
#
#                Insult to modesty of Women  \
# STATE/UT
# uttar pradesh                       53130
#
#                Cruelty by Husband or his Relatives  Importation of Girls  \
# STATE/UT
# uttar pradesh                               193738                     6
#
#                 Total
# STATE/UT
# uttar pradesh  582398

# %%
crime_up=pd.DataFrame(columns=['Crimes in UP',"total"])
for crime in crimes:
    crime_up=crime_up.append({'Crimes in UP':crime ,'total':crimedata_up[crime].sum(axis=0)},ignore_index=True)
    
crime_up=crime_up.sort_values(by='total',ascending=False)

print("***** Total count of each crime from 2001 to 2014 in Uttar Pradesh *****")
print()
crime_up
# Out:
# ***** Total count of each crime from 2001 to 2014 in Uttar Pradesh *****
#                                         Crimes in UP   total
# 5                Cruelty by Husband or his Relatives  193738
# 1                           Kidnapping and Abduction  135906
# 3  Assault on women with intent to outrage her mo...   91212
# 2                                       Dowry Deaths   57256
# 4                         Insult to modesty of Women   53130
# 0                                               Rape   51150
# 6                               Importation of Girls       6

# %% [markdown]
# **Percentage Distribution of Crimes in Uttar Pradesh from 2001 to 2014**

# %%
fig=plt.figure(figsize=(20,5))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


plt.pie(crime_up['total'],colors=colors,labels=crime_up['Crimes in UP'],autopct='%1.2f%%')
plt.title("Crime Distribution in Uttar Pradesh",fontweight='bold',fontsize=15)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=crime_up,x="Crimes in UP",y='total', color='brown')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 60)
plt.text(2,155000,"Crime rate against women in Uttar Pradesh\nHighest Crime : Cruelty by husband",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("total_crimes",fontweight='bold')
plt.title("Total Number Of Crimes In Uttar Pradesh",fontweight='bold',fontsize=20)
plt.show()

# %% [markdown]
# **Total number of crimes from in Uttar Pradesh year wise 2001 to 2014**

# %%
up_year_data=crime_data.loc[crime_data['STATE/UT']=='uttar pradesh']

up_yearwise_data=pd.DataFrame()
for i in columns:
    crimes_up_data=up_year_data.groupby(['Year'])[i].sum()
    up_yearwise_data[i]=crimes_up_data

print("***** Total number of crimes from in Uttar Pradesh year wise 2001 to 2014*****")
print()
up_yearwise_data=up_yearwise_data.sort_values(by='Total',ascending=False)
up_yearwise_data
# Out:
# ***** Total number of crimes from in Uttar Pradesh year wise 2001 to 2014*****
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2014  6934                     21252          4938
# 2013  6100                     19474          4670
# 2008  3742                      8878          4474
# 2012  3926                     15820          4488
# 2009  3518                     10156          4464
# 2011  4084                     15050          4644
# 2007  3296                      6726          4152
# 2010  3126                     10936          4434
# 2001  3916                      5758          4422
# 2006  2628                      5102          3596
# 2002  2830                      4596          3786
# 2004  2794                      4648          3416
# 2005  2434                      4512          3128
# 2003  1822                      2998          2644
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2014                                              17210
# 2013                                              14606
# 2008                                               5910
# 2012                                               6494
# 2009                                               5564
# 2011                                               6910
# 2007                                               5044
# 2010                                               5586
# 2001                                               5740
# 2006                                               4192
# 2002                                               4290
# 2004                                               3800
# 2005                                               3670
# 2003                                               2196
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2014                          58                                20942
# 2013                          50                                17562
# 2008                        6748                                16624
# 2012                          16                                15322
# 2009                        5048                                17132
# 2011                           6                                14242
# 2007                        5764                                15300
# 2010                          22                                15956
# 2001                        5150                                14730
# 2006                        5428                                10408
# 2002                        3774                                11358
# 2004                        5364                                 9900
# 2005                        5762                                 9010
# 2003                        9940                                 5252
#
#       Importation of Girls  Total
# Year
# 2014                     0  71334
# 2013                     0  62462
# 2008                     0  46376
# 2012                     0  46066
# 2009                     0  45882
# 2011                     0  44936
# 2007                     0  40282
# 2010                     0  40060
# 2001                     0  39716
# 2006                     0  31354
# 2002                     0  30634
# 2004                     6  29928
# 2005                     0  28516
# 2003                     0  24852

# %%
fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=up_yearwise_data,x=up_yearwise_data.index,y='Total',palette='rocket_r')
ax.set_xticklabels(ax.get_xticklabels())
plt.text(0.5,65000,"Crime rate against women in UP yearwise",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total",fontweight='bold')
plt.title("Total Number Of Crimes In Each Year",fontweight='bold',fontsize=20)

plt.show()

# %%
plt.figure(figsize=(13,6)).patch.set_facecolor("#F1EDD7FF")
plt.pie(up_yearwise_data["Total"],labels=up_yearwise_data.index,autopct='%1.2f%%',counterclock=False)
plt.tight_layout()

# %% [markdown]
# **Timeline Analysis of Different Categories of Crime at Different Period of Time**

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


ax.grid(linestyle="--",axis="y",color='gray')

lower_year=2001
upper_year=2014
arr=np.array([i for i in range(lower_year, upper_year+1)])

a=sns.lineplot(data=up_yearwise_data,palette='rocket_r',linestyle="dashed")#,x=arr,y='Rape',hue_order=crimes,palette='rocket_r')

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
#plt.text(0.5,540000,"Crime rate against women increases year by year",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("crime rate",fontweight='bold')
plt.title("Crime Rate against Women in Uttar Pradesh",fontweight='bold',fontsize=20)
plt.show()
# Out:
# C:\Users\gbeme\AppData\Local\Temp/ipykernel_16964/2879001058.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# **2001 VS 2014 In UP**

# %%
data_2001=up_yearwise_data.loc[annual_crimes.index==2001]
data_2014=up_yearwise_data.loc[annual_crimes.index==2014]

data_2001=data_2001.drop(["Total"],axis=1)
data_2014=data_2014.drop(["Total"],axis=1)
crimes_in_2001=list(data_2001.iloc[0])
crimes_in_2014=list(data_2014.iloc[0])

f,ax=plt.subplots(1,2,figsize=(20,8))
f.patch.set_facecolor('#F2EDD7FF')
#Setting background and foreground color
for j in range(0,2):
    ax[j].set_facecolor('#F2EDD7FF')
    
ax[0].pie(crimes_in_2001,autopct='%1.2f%%', explode=[0,0.05,0.0,0.0,0.0,0.03,0])
ax[0].text(-0.15,1.4,"2001 In UP",fontweight='bold',fontsize=20)
ax[1].pie(crimes_in_2014,autopct='%1.2f%%', explode=[0.03,0.0,0.0,0.0,0.05,0.03,0])
ax[0].text(3.4,1.4,"2014 In UP",fontweight='bold',fontsize=20)
ax[1].legend(labels=data_2001.columns,loc='lower right')

plt.show()

# %% [markdown]
# **2. Andhra Pradesh**

# %%
ap_data=state_crimedata.loc[state_crimedata.index=='andhra pradesh']

crime_ap_data=pd.DataFrame(columns=['Crimes in AP',"total"])
for i in crimes:
    crime_ap_data=crime_ap_data.append({'Crimes in AP':i ,'total':ap_data[i].sum(axis=0)},ignore_index=True)
    
crime_ap_data=crime_ap_data.sort_values(by='total',ascending=False)

print("***** Total count of each crime from 2001 to 2014 in Andhra Pradesh *****")
print()
crime_ap_data
# Out:
# ***** Total count of each crime from 2001 to 2014 in Andhra Pradesh *****
#                                         Crimes in AP   total
# 5                Cruelty by Husband or his Relatives  280906
# 3  Assault on women with intent to outrage her mo...  126952
# 4                         Insult to modesty of Women   86964
# 1                           Kidnapping and Abduction   34504
# 0                                               Rape   32150
# 2                                       Dowry Deaths   13844
# 6                               Importation of Girls      34

# %% [markdown]
# **Percentage Distribution of Crimes in from 2001 to 2014**

# %%
fig=plt.figure(figsize=(20,7))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


plt.pie(crime_ap_data['total'],colors=colors,labels=crime_ap_data['Crimes in AP'], explode= (0.05,0,0.03,0,0,0.08,0.05),autopct='%1.2f%%', shadow=True)
plt.title("Crime Distribution in Andhra Pradesh",fontweight='bold',fontsize=15)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=crime_ap_data,x="Crimes in AP",y='total',color='brown')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 60)
plt.text(2,155000,"Crime rate against women in Andhra Pradesh\nHighest Crime : Cruelty by husband",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("total_crimes",fontweight='bold')
plt.title("Total Number Of Crimes In Andhra Pradesh",fontweight='bold',fontsize=20)

plt.show()

# %% [markdown]
# **Total number of crimes from in Andhra Pradesh year wise 2001 to 2014**

# %%
ap_year_data=crime_data.loc[crime_data['STATE/UT']=='andhra pradesh']

ap_yearwise_data=pd.DataFrame()
for i in columns:
    crimes_ap_data=ap_year_data.groupby(['Year'])[i].sum()
    ap_yearwise_data[i]=crimes_ap_data

print("***** Total number of crimes from in Andhra Pradesh year wise 2001 to 2014*****")
print()
ap_yearwise_data=ap_yearwise_data.sort_values(by='Total',ascending=False)
ap_yearwise_data
# Out:
# ***** Total number of crimes from in Andhra Pradesh year wise 2001 to 2014*****
#       Rape  Kidnapping and Abduction  Dowry Deaths  \
# Year
# 2013  3270                      3190           984
# 2011  2884                      3224          1198
# 2012  2682                      2806          1008
# 2010  2724                      3062          1176
# 2009  2376                      3052          1092
# 2007  2140                      3128          1226
# 2008  2514                      2792          1112
# 2006  2098                      2658          1038
# 2005  1870                      1990           886
# 2004  2032                      2060          1024
# 2003  1892                      1862           932
# 2014  1922                      1442           430
# 2002  2004                      1708           898
# 2001  1742                      1530           840
#
#       Assault on women with intent to outrage her modesty  \
# Year
# 2013                                              13860
# 2011                                               9698
# 2012                                               9632
# 2010                                               9268
# 2009                                              10294
# 2007                                               8812
# 2008                                               9460
# 2006                                               9068
# 2005                                               7190
# 2004                                               7634
# 2003                                               8256
# 2014                                               9094
# 2002                                               7598
# 2001                                               7088
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# Year
# 2013                        9404                                30168
# 2011                        7316                                26752
# 2012                        7428                                26778
# 2010                        9124                                24160
# 2009                        7040                                22594
# 2007                        6632                                22670
# 2008                        7102                                20612
# 2006                        4822                                18328
# 2005                        5016                                17392
# 2004                        4620                                16776
# 2003                        4572                                16334
# 2014                        5298                                12724
# 2002                        4048                                14036
# 2001                        4542                                11582
#
#       Importation of Girls  Total
# Year
# 2013                     0  60876
# 2011                     0  51072
# 2012                     0  50334
# 2010                     0  49514
# 2009                     0  46448
# 2007                     0  44608
# 2008                     0  43592
# 2006                     0  38012
# 2005                     6  34350
# 2004                     4  34150
# 2003                    10  33858
# 2014                     0  30910
# 2002                     0  30292
# 2001                    14  27338

# %%
fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")


ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=ap_yearwise_data,x=ap_yearwise_data.index,y='Total',palette='rocket_r')
ax.set_xticklabels(ax.get_xticklabels())
plt.text(0.5,55000,"Crime rate against women in AP yearwise",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("total_crimes",fontweight='bold')
plt.title("Total Number Of Crimes In Each Year",fontweight='bold',fontsize=20)

plt.show()

# %% [markdown]
# **Crime Rate against Women in Andhra Pradesh**

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

ax.grid(linestyle="--",axis="y",color='gray')

a=sns.lineplot(data=ap_yearwise_data,palette='rocket_r',linestyle="dashed")

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("crime rate",fontweight='bold')
plt.title("Crime Rate against Women in Andhra Pradesh",fontweight='bold',fontsize=20)
plt.show()
# Out:
# C:\Users\gbeme\AppData\Local\Temp/ipykernel_16964/4239205940.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# **2001 VS 2014 IN ANDHRA PRADESH**

# %%
data_2001=ap_yearwise_data.loc[annual_crimes.index==2001]
data_2014=ap_yearwise_data.loc[annual_crimes.index==2014]

data_2001=data_2001.drop(["Total"],axis=1)
data_2014=data_2014.drop(["Total"],axis=1)
crimes_in_2001=list(data_2001.iloc[0])
crimes_in_2014=list(data_2014.iloc[0])

f,ax=plt.subplots(1,2,figsize=(20,8))
f.patch.set_facecolor('#F2EDD7FF')
#Setting background and foreground color
for j in range(0,2):
    ax[j].set_facecolor('#F2EDD7FF')
    
ax[0].pie(crimes_in_2001,autopct='%1.2f%%',explode= (0.0,0,0.03,0,0,0.03,0.0), pctdistance=0.5)
ax[0].text(-0.8,1.4,"2001 In Andhra Pradesh",fontweight='bold',fontsize=20)
ax[1].pie(crimes_in_2014,autopct='%1.2f%%', explode= (0.02,0,0.03,0,0,0.03,0))
ax[0].text(3,1.4,"2014 In Andhra Pradesh",fontweight='bold',fontsize=20)
ax[0].legend(labels=data_2001.columns,loc='best')

plt.show()

# %% [markdown]
# **3. West Bengal**

# %%
wb_data=state_crimedata.loc[state_crimedata.index=='west bengal']

crime_wb_data=pd.DataFrame(columns=['Crimes in WB',"total"])
for i in crimes:
    crime_wb_data=crime_wb_data.append({'Crimes in WB':i ,'total':wb_data[i].sum(axis=0)},ignore_index=True)
    
crime_wb_data=crime_wb_data.sort_values(by='total',ascending=False)

print("***** Total count of each crime from 2001 to 2014 in West Bengal *****")
print()
crime_wb_data
# Out:
# ***** Total count of each crime from 2001 to 2014 in West Bengal *****
#                                         Crimes in WB   total
# 5                Cruelty by Husband or his Relatives  344124
# 3  Assault on women with intent to outrage her mo...   66908
# 1                           Kidnapping and Abduction   61158
# 0                                               Rape   47876
# 2                                       Dowry Deaths   12308
# 4                         Insult to modesty of Women    5348
# 6                               Importation of Girls     254

# %%
fig=plt.figure(figsize=(20,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

plt.pie(crime_wb_data['total'],colors=colors,labels=crime_wb_data['Crimes in WB'],autopct='%1.2f%%', explode= (0.05,0,0.03,0,0,0.2,0.07))
plt.title("Crime Distribution in West Bengal",fontweight='bold',fontsize=15)
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=crime_wb_data,x="Crimes in WB",y='total',color='brown')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 70)
plt.text(2,420000,"Crime rate against women in West Bengal\nHighest Crime : Cruelty by husband",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Crimes",fontweight='bold')
plt.ylabel("total_crimes",fontweight='bold')
plt.title("Total Number Of Crimes In West Bengal",fontweight='bold',fontsize=20)

plt.show()

# %%
crime_wb=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls','Total']

wb_year_data=crime_data.loc[crime_data['STATE/UT']=='west bengal']

wb_yearwise_data=pd.DataFrame()
for i in crime_wb:
    crimes_wb_data=wb_year_data.groupby(['Year'])[i].sum()
    wb_yearwise_data[i]=crimes_wb_data

print("***** Total number of crimes from in Andhra Pradesh year wise 2001 to 2014*****")
print()
wb_yearwise_data=wb_yearwise_data.sort_values(by='Total',ascending=False)
#df1_wb_yearwise
fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

ax.grid(linestyle="--",axis="y",color='gray')

a=sns.barplot(data=wb_yearwise_data,x=wb_yearwise_data.index,y='Total',palette='rocket_r')
ax.set_xticklabels(ax.get_xticklabels())
plt.text(0.5,55000,"Crime rate against women in West Bengal yearwise",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("total_crimes",fontweight='bold')
plt.title("Total Number Of Crimes In Each Year",fontweight='bold',fontsize=20)
plt.show()
# Out:
# ***** Total number of crimes from in Andhra Pradesh year wise 2001 to 2014*****

# %%
sns.set_theme(style='white',context='notebook')

fig=plt.figure(figsize=(16,8))

ax=plt.axes()
ax.set_facecolor("#F2EDD7FF")
fig.patch.set_facecolor("#F2EDD7FF")

ax.grid(linestyle="--",axis="y",color='gray')

a=sns.lineplot(data=wb_yearwise_data,palette='rocket_r',linestyle="dashed")#,x=arr,y='Rape',hue_order=crimes,palette='rocket_r')

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
#plt.text(0.5,60000,"Crime rate against women increases year by year",fontweight='bold',fontsize=20)
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel("Year",fontweight='bold')
plt.ylabel("crime rate",fontweight='bold')
plt.title("Crime Rate against Women in West Bengal",fontweight='bold',fontsize=20)
plt.show()
# Out:
# C:\Users\gbeme\AppData\Local\Temp/ipykernel_16964/1768141656.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
data_2001=wb_yearwise_data.loc[annual_crimes.index==2001]
data_2014=wb_yearwise_data.loc[annual_crimes.index==2014]

data_2001=data_2001.drop(["Total"],axis=1)
data_2014=data_2014.drop(["Total"],axis=1)
crimes_in_2001=list(data_2001.iloc[0])
crimes_in_2014=list(data_2014.iloc[0])

f,ax=plt.subplots(1,2,figsize=(20,8))
f.patch.set_facecolor('#F2EDD7FF')
#Setting background and foreground color
for j in range(0,2):
    ax[j].set_facecolor('#F2EDD7FF')
    
ax[0].pie(crimes_in_2001,autopct='%1.2f%%', explode= (0,0,0.03,0,0,0.03,0), pctdistance=0.5)
ax[0].text(-0.7,1.4,"2001 In West Bengal",fontweight='bold',fontsize=20)
ax[1].pie(crimes_in_2014,autopct='%1.2f%%', explode= (0,0,0,0,0.03,0.03,0), pctdistance=0.5)
ax[0].text(3.0,1.4,"2014 In West Bengal",fontweight='bold',fontsize=20)
ax[0].legend(labels=data_2001.columns,loc='best')

plt.show()

# %%
plt.figure(figsize=(13,7)).patch.set_facecolor("#F1EDD7FF")
plt.pie(wb_yearwise_data["Total"],labels=wb_yearwise_data.index,autopct='%1.2f%%',counterclock=False)
plt.title("Percent of crimes In West Bengal by year",fontweight='bold',fontsize=20)
plt.tight_layout()

# %% [markdown]
# # CORRELATION PLOT

# %%
#Check for correlation  between crime categories 
dataplot=sns.heatmap(crime_data.drop('Total', axis=1).corr(), annot=True)
dataplot
# Out:
# <AxesSubplot:>

# %% [markdown]
# # THANK YOU!!                                         (TEAM COLAB)
